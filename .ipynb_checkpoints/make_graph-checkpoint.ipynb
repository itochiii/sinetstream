# %% [markdown]
# 全部表示すると訳わかんないので暗号化だけとかデータサイズだけとかで比較する
# msg_count_rate, msg_bytes_rate
#
# 条件
# - 暗号化する or しない(デフォルト)
# - 圧縮する or しない(デフォルト)
# - メッセージサイズ1KB or 10KB or 100KB
# - kafka or mosquitto
#
# それぞれで2回測定
# メッセージサイズはとりあえず10KBを基準にする

# %% [markdown]
# それぞれ1stと2nd、kafkaとmqttを並べて表示.
# - 暗号化比較
#  - aes-coff-10-_-kafka vs. plain-coff-10-_-kafka
#  - aes-coff-10-_-mqtt vs. plain-coff-10-_-mqtt
# - メッセージサイズ比較
#  - plain-coff-1-_-kafka vs. plain-coff-10-_-kafka vs. plain-coff-100-_-kafka
#  - plain-coff-1-_-mqtt vs. plain-coff-10-_-mqtt vs. plain-coff-100-_-mqtt
# - 圧縮比較
#  - plain-con-10-_-kafka vs. plain-coff-10-_-kafka
#  - plain-con-10-_-mqtt vs. plain-coff-10-_-mqtt

# %%
import pandas as pd
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
aes = ["aes", "plain"]
con = ["con", "coff"]
size = ["1", "10", "100"]
broker = ["kafka", "mosquitto"]
order = ["1st", "2nd"]

kafka_w_msg_count =np.zeros((2, 2))
mqtt_w_msg_count =np.zeros((2, 2))
kafka_r_msg_count =np.zeros((2, 2))
mqtt_r_msg_count =np.zeros((2, 2))
kafka_w_bytes =np.zeros((2, 2))
mqtt_w_bytes =np.zeros((2, 2))
kafka_r_bytes =np.zeros((2, 2))
mqtt_r_bytes =np.zeros((2, 2))

# グラフの情報
fig_w = 12
fig_h = 12
margin = 0.3
w = 0.3
x1 = 1
x2 = 3
x3 = 5
label_lst = ["kafka_1st", "kafka_2nd", "mqtt_1st", "mqtt_2nd"]
# print(kafka_w_msg_count.shape)

# %% [markdown]
# ### 暗号化比較

# %%
for i, a in enumerate(aes):
    for b in broker:
        for j, o in enumerate(order): 
            file = a+"-coff-10-"+o+"-"+b+".tsv"
            df = pd.read_table("result/" +  file)
            if b == "kafka":
                kafka_w_msg_count[j][i] = df["writer_msg_count_rate"][0]
                kafka_r_msg_count[j][i] = df["reader_msg_count_rate"][0]
                kafka_w_bytes[j][i] = df["writer_msg_bytes_rate"][0]
                kafka_r_bytes[j][i] = df["reader_msg_bytes_rate"][0]
            else:
                mqtt_w_msg_count[j][i] = df["writer_msg_count_rate"][0]
                mqtt_r_msg_count[j][i] = df["reader_msg_count_rate"][0]
                mqtt_w_bytes[j][i] = df["writer_msg_bytes_rate"][0]
                mqtt_r_bytes[j][i] = df["reader_msg_bytes_rate"][0]
# aes-1st-kafka, plain-1st-kafka, aes-2nd-kafka, plain-2nd-kafka
# 49.5049505, 107.9136691, 104.1666667, 155.4404145

# %%
data_lst_w = [kafka_w_msg_count[0], kafka_w_msg_count[1], mqtt_w_msg_count[0], mqtt_w_msg_count[1]]
data_lst_r = [kafka_r_msg_count[0], kafka_r_msg_count[1], mqtt_r_msg_count[0], mqtt_r_msg_count[1]]
bytes_lst_w = [kafka_w_bytes[0], kafka_w_bytes[1], mqtt_w_bytes[0], mqtt_w_bytes[1]]
bytes_lst_r = [kafka_r_bytes[0], kafka_r_bytes[1], mqtt_r_bytes[0], mqtt_r_bytes[1]]

# グラフの準備
fig, ax = plt.subplots(2, 2, figsize=(fig_w, fig_h))
# 余白
plt.subplots_adjust(hspace=margin)
# 描画
for i, d in enumerate(data_lst_w):
    ax[0, 0].bar([x1+w*i, x2+w*i], d, w, label=label_lst[i])
for i, d in enumerate(data_lst_r):
    ax[0, 1].bar([x1+w*i, x2+w*i], d, w, label=label_lst[i])
for i, d in enumerate(bytes_lst_w):
    ax[1, 0].bar([x1+w*i, x2+w*i], d, w, label=label_lst[i])
for i, d in enumerate(bytes_lst_r):
    ax[1, 1].bar([x1+w*i, x2+w*i], d, w, label=label_lst[i])
    
for i in range(2):
    for j in range(2):
    # 凡例
        ax[i][j].legend(loc=2)
        ax[i][j].set_xticks([x1+w+w/2, x2+w+w/2])
        ax[i][j].set_xticklabels(aes)
ax[0, 0].set_ylabel('writer_msg_count_rate')
ax[0, 1].set_ylabel('reader_msg_count_rate')
ax[1, 0].set_ylabel('writer_msg_bytes_rate')
ax[1, 1].set_ylabel('reader_msg_bytes_rate')
fig.suptitle("data_compression=false, message_size = 10KB")
plt.show()

# %% [markdown]
# ### 圧縮比較

# %%
for i, c in enumerate(con):
    for b in broker:
        for j, o in enumerate(order): 
            file = "plain-"+c+"-10-"+o+"-"+b+".tsv"
            df = pd.read_table("result/" +  file)
            if b == "kafka":
                kafka_w_msg_count[j][i] = df["writer_msg_count_rate"][0]
                kafka_r_msg_count[j][i] = df["reader_msg_count_rate"][0]
                kafka_w_bytes[j][i] = df["writer_msg_bytes_rate"][0]
                kafka_r_bytes[j][i] = df["reader_msg_bytes_rate"][0]
            else:
                mqtt_w_msg_count[j][i] = df["writer_msg_count_rate"][0]
                mqtt_r_msg_count[j][i] = df["reader_msg_count_rate"][0]
                mqtt_w_bytes[j][i] = df["writer_msg_bytes_rate"][0]
                mqtt_r_bytes[j][i] = df["reader_msg_bytes_rate"][0]

# %%
data_lst_w = [kafka_w_msg_count[0], kafka_w_msg_count[1], mqtt_w_msg_count[0], mqtt_w_msg_count[1]]
data_lst_r = [kafka_r_msg_count[0], kafka_r_msg_count[1], mqtt_r_msg_count[0], mqtt_r_msg_count[1]]
bytes_lst_w = [kafka_w_bytes[0], kafka_w_bytes[1], mqtt_w_bytes[0], mqtt_w_bytes[1]]
bytes_lst_r = [kafka_r_bytes[0], kafka_r_bytes[1], mqtt_r_bytes[0], mqtt_r_bytes[1]]

# グラフの準備
fig, ax = plt.subplots(2, 2, figsize=(fig_w, fig_h))
# 余白
plt.subplots_adjust(hspace=margin)
# 描画
for i, d in enumerate(data_lst_w):
    ax[0, 0].bar([x1+w*i, x2+w*i], d, w, label=label_lst[i])
for i, d in enumerate(data_lst_r):
    ax[0, 1].bar([x1+w*i, x2+w*i], d, w, label=label_lst[i])
for i, d in enumerate(bytes_lst_w):
    ax[1, 0].bar([x1+w*i, x2+w*i], d, w, label=label_lst[i])
for i, d in enumerate(bytes_lst_r):
    ax[1, 1].bar([x1+w*i, x2+w*i], d, w, label=label_lst[i])
    
for i in range(2):
    for j in range(2):
    # 凡例
        ax[i][j].legend(loc=2)
        ax[i][j].set_xticks([x1+w+w/2, x2+w+w/2])
        ax[i][j].set_xticklabels(con)
ax[0, 0].set_ylabel('writer_msg_count_rate')
ax[0, 1].set_ylabel('reader_msg_count_rate')
ax[1, 0].set_ylabel('writer_msg_bytes_rate')
ax[1, 1].set_ylabel('reader_msg_bytes_rate')
fig.suptitle("crypto=false, message_size = 10KB")
plt.show()

# %% [markdown]
# ### メッセージサイズ比較

# %%
kafka_w_msg_count =np.zeros((2, 3))
mqtt_w_msg_count =np.zeros((2, 3))
kafka_r_msg_count =np.zeros((2, 3))
mqtt_r_msg_count =np.zeros((2, 3))
kafka_w_bytes =np.zeros((2, 3))
mqtt_w_bytes =np.zeros((2, 3))
kafka_r_bytes =np.zeros((2, 3))
mqtt_r_bytes =np.zeros((2, 3))

# [[1st_1, 1st_10, 1st_100], [2nd_1, 2nd_10, 2nd_100]]

# %%
for i, s in enumerate(size):
    for b in broker:
        for j, o in enumerate(order): 
            file = "plain-coff-"+s+"-"+o+"-"+b+".tsv"
            df = pd.read_table("result/" +  file)
            if b == "kafka":
                kafka_w_msg_count[j][i] = df["writer_msg_count_rate"][0]
                kafka_r_msg_count[j][i] = df["reader_msg_count_rate"][0]
                kafka_w_bytes[j][i] = df["writer_msg_bytes_rate"][0]
                kafka_r_bytes[j][i] = df["reader_msg_bytes_rate"][0]
            else:
                mqtt_w_msg_count[j][i] = df["writer_msg_count_rate"][0]
                mqtt_r_msg_count[j][i] = df["reader_msg_count_rate"][0]
                mqtt_w_bytes[j][i] = df["writer_msg_bytes_rate"][0]
                mqtt_r_bytes[j][i] = df["reader_msg_bytes_rate"][0]

# 93.16770186, 58.82352941,
# Out:
# [[93.16770186 58.82352941 63.15789474]
#  [99.00990099 78.32898172 89.55223881]]

# %%
data_lst_w = [kafka_w_msg_count[0], kafka_w_msg_count[1], mqtt_w_msg_count[0], mqtt_w_msg_count[1]]
data_lst_r = [kafka_r_msg_count[0], kafka_r_msg_count[1], mqtt_r_msg_count[0], mqtt_r_msg_count[1]]
bytes_lst_w = [kafka_w_bytes[0], kafka_w_bytes[1], mqtt_w_bytes[0], mqtt_w_bytes[1]]
bytes_lst_r = [kafka_r_bytes[0], kafka_r_bytes[1], mqtt_r_bytes[0], mqtt_r_bytes[1]]

# グラフの準備
fig, ax = plt.subplots(2, 2, figsize=(fig_w, fig_h))
# 余白
plt.subplots_adjust(hspace=margin)
# 描画
for i, d in enumerate(data_lst_w):
    ax[0, 0].bar([x1+w*i, x2+w*i, x3+w*i], d, w, label=label_lst[i])
for i, d in enumerate(data_lst_r):
    ax[0, 1].bar([x1+w*i, x2+w*i, x3+w*i], d, w, label=label_lst[i])
for i, d in enumerate(bytes_lst_w):
    ax[1, 0].bar([x1+w*i, x2+w*i, x3+w*i], d, w, label=label_lst[i])
for i, d in enumerate(bytes_lst_r):
    ax[1, 1].bar([x1+w*i, x2+w*i, x3+w*i], d, w, label=label_lst[i])
    
for i in range(2):
    for j in range(2):
    # 凡例
        ax[i][j].legend(loc=2)
        ax[i][j].set_xticks([x1+w+w/2, x2+w+w/2, x3+w+w/2])
        ax[i][j].set_xticklabels(size)
ax[0, 0].set_ylabel('writer_msg_count_rate')
ax[0, 1].set_ylabel('reader_msg_count_rate')
ax[1, 0].set_ylabel('writer_msg_bytes_rate')
ax[1, 1].set_ylabel('reader_msg_bytes_rate')
fig.suptitle("crypto=plain, message_size = 10KB")
plt.show()
# Out:
# [array([93.16770186, 58.82352941, 63.15789474]), array([99.00990099, 78.32898172, 89.55223881]), array([141.50943396, 132.15859031, 127.11864407]), array([112.78195489, 152.28426396, 121.45748988])]
